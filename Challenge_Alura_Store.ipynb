# %%
from google.colab import userdata
import os
USER = 'HoustonFranz'
TOKEN = userdata.get('GITHUB_TOKEN')
REPO = 'Challenge-Alura-Store'
url_repositorio = f"https://{USER}:{TOKEN}@github.com/{USER}/{REPO}.git"
# !git clone {url_repositorio}
# Out:
# fatal: destination path 'Challenge-Alura-Store' already exists and is not an empty directory.

# %%
# %cd {REPO}
# !ls
# !git status
# Out:
# /content/Challenge-Alura-Store/Challenge-Alura-Store
# README.md  requirements.txt
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# Configura tu identidad si es la primera vez en esta sesión
# !git config --global user.email "gaonamendozafranz@gmail.com"
# !git config --global user.name "Houston Franz"

# %%
# Eliminar las carpetas creadas
# !rm -rf data notebook reports

# Eliminar los archivos creados
# !rm .gitignore requirements.txt README.md

# %%
# 1. Preparar los archivos (eliminar del seguimiento de Git)
# !git add .

# 2. Ponerle un nombre a este avance
# !git commit -m "Eliminando archivos y estructura inicial del proyecto creados desde Colab."

# 3. Subirlo a GitHub
# !git push origin main
# Out:
# [main 63fae38] Eliminando archivos y estructura inicial del proyecto creados desde Colab.
#  3 files changed, 5 deletions(-)
#  delete mode 100644 .gitignore
#  delete mode 100644 README.md
#  delete mode 100644 requirements.txt
# remote: Invalid username or token. Password authentication is not supported for Git operations.
# fatal: Authentication failed for 'https://github.com/HoustonFranz/Challenge-Alura-Store.git/'
